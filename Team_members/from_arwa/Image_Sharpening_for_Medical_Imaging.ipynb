# %% [markdown]
# # Image Sharpening for Medical Imaging

# %% [markdown]
# As a radiologist, I want to sharpen an X-ray image so that fine details in bones and tissues become more visible, helping me make a more accurate diagnosis.

# %% [markdown]
# imports

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import PIL as Image

# %% [markdown]
# - Load the provided X-ray image.

# %%
x_ray = cv2.imread("C:/Users/bbuser/Desktop/xray.png")
x_ray.shape
# Out:
# (899, 662, 3)

# %%
plt.imshow(x_ray)
plt.title('X-ray Image')
plt.axis('off')
plt.show()

# %% [markdown]
# - Convert to grayscale (if not already).

# %%
gray = cv2.cvtColor(x_ray, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
plt.title('Grey-scale X-ray Image')
plt.axis('off')
plt.show()

# %% [markdown]
# - Apply a sharpening kernel (e.g., [[0,-1,0], [-1,5,-1], [0,-1,0]]).

# %% [markdown]
# - Compare the sharpened image to the original.

# %% [markdown]
# - Save the processed image.
