# %% [markdown]
# # News Search engine

# %% [markdown]
# #### imports

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import matplotlib as plt 
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer 
from collections import Counter
from wordcloud import WordCloud
import re
import nltk
from nltk.corpus import stopwords
import random
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# ### data preprocessing

# %% [markdown]
# - Load dataset and filter categories.

# %%
df = pd.read_json(r"data/News_Category_Dataset_v3.json", lines=True)
df
# Out:
#                                                      link  \
# 0       https://www.huffpost.com/entry/covid-boosters-...
# 1       https://www.huffpost.com/entry/american-airlin...
# 2       https://www.huffpost.com/entry/funniest-tweets...
# 3       https://www.huffpost.com/entry/funniest-parent...
# 4       https://www.huffpost.com/entry/amy-cooper-lose...
# ...                                                   ...
# 209522  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 209523  https://www.huffingtonpost.com/entry/maria-sha...
# 209524  https://www.huffingtonpost.com/entry/super-bow...
# 209525  https://www.huffingtonpost.com/entry/aldon-smi...
# 209526  https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                                  headline   category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2       23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3       The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
# ...                                                   ...        ...
# 209522  RIM CEO Thorsten Heins' 'Significant' Plans Fo...       TECH
# 209523  Maria Sharapova Stunned By Victoria Azarenka I...     SPORTS
# 209524  Giants Over Patriots, Jets Over Colts Among  M...     SPORTS
# 209525  Aldon Smith Arrested: 49ers Linebacker Busted ...     SPORTS
# 209526  Dwight Howard Rips Teammates After Magic Loss ...     SPORTS
#
#                                         short_description  \
# 0       Health experts said it is too early to predict...
# 1       He was subdued by passengers and crew when he ...
# 2       "Until you have a dog you don't understand wha...
# 3       "Accidentally put grown-up toothpaste on my to...
# 4       Amy Cooper accused investment firm Franklin Te...
# ...                                                   ...
# 209522  Verizon Wireless and AT&T are already promotin...
# 209523  Afterward, Azarenka, more effusive with the pr...
# 209524  Leading up to Super Bowl XLVI, the most talked...
# 209525  CORRECTION: An earlier version of this story i...
# 209526  The five-time all-star center tore into his te...
#
#                      authors       date
# 0       Carla K. Johnson, AP 2022-09-23
# 1             Mary Papenfuss 2022-09-23
# 2              Elyse Wanshel 2022-09-23
# 3           Caroline Bologna 2022-09-23
# 4             Nina Golgowski 2022-09-22
# ...                      ...        ...
# 209522      Reuters, Reuters 2012-01-28
# 209523                       2012-01-28
# 209524                       2012-01-28
# 209525                       2012-01-28
# 209526                       2012-01-28
#
# [209527 rows x 6 columns]

# %% [markdown]
# - Balance dataset (1000 per category).

# %%
categories = ["POLITICS", "TRAVEL", "SPORTS", "HOME & LIVING"]
df_category = df[df['category'].isin(categories)]
df_category["category"].value_counts()
# Out:
# category
# POLITICS         35602
# TRAVEL            9900
# SPORTS            5077
# HOME & LIVING     4320
# Name: count, dtype: int64

# %%
df_balanced = (
    df_category.groupby("category", group_keys=False)
      .apply(lambda x: x.sample(n=1000, random_state=42))
      .reset_index(drop=True)
)
# Out:
# C:\Users\bbuser\AppData\Local\Temp\ipykernel_20036\1622274842.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(n=1000, random_state=42))

# %% [markdown]
# - Keep only headline and category.

# %%
df_balanced = df_balanced[["headline", "category"]].dropna()

# %%
df_balanced.shape
# Out:
# (4000, 2)

# %% [markdown]
# #### Vectorization

# %%
vectorizer = TfidfVectorizer(stop_words="english", max_features=5000)
X = vectorizer.fit_transform(df_balanced["headline"])

print("TF-IDF matrix shape:", X.shape)  # (4000, ~5000)
# Out:
# TF-IDF matrix shape: (4000, 5000)

# %% [markdown]
# #### Search Implementation

# %%
def search(query, top_n=10):
    # Transform query into TF-IDF space
    q_vec = vectorizer.transform([query])
    # Compute cosine similarity with all headline vectors
    sims = cosine_similarity(q_vec, X).flatten()
    # Get top N indices
    top_idx = np.argsort(sims)[::-1][:top_n]
    
    results = []
    for rank, i in enumerate(top_idx, 1):
        results.append({
            "Rank": rank,
            "Headline": df_balanced.iloc[i]["headline"],
            "Category": df_balanced.iloc[i]["category"],
            "Similarity Score": round(sims[i], 3)
        })
    return pd.DataFrame(results)

# Example usage
query = "president election"
results_df = search(query, top_n=10)
results_df
# Out:
#    Rank                                           Headline       Category  \
# 0     1  This President's Tweeting Is Squandering Our Time       POLITICS
# 1     2              Protecting America From Its President       POLITICS
# 2     3  We’re Still, Somehow, A Year Away From The Pre...       POLITICS
# 3     4  Obama Has Some Issues With How The Media Are C...       POLITICS
# 4     5  8 Problems You May Encounter Going To Vote In ...  HOME & LIVING
# 5     6  True Patriotism Requires Supporting Every Pres...       POLITICS
# 6     7  Shonda Rhimes Says 2016 Election Is Mirroring ...       POLITICS
# 7     8  Lying To The Press Is Nothing New For The Pres...       POLITICS
# 8     9  Are President Trump's Supporters Embarrassed T...       POLITICS
# 9    10  President Obama Hawaii: What To Do On Oahu (PH...         TRAVEL
#
#    Similarity Score
# 0             0.490
# 1             0.487
# 2             0.377
# 3             0.354
# 4             0.342
# 5             0.315
# 6             0.309
# 7             0.305
# 8             0.302
# 9             0.294

# %% [markdown]
# #### User experience

# %%
search("president election")
# Out:
#    Rank                                           Headline       Category  \
# 0     1  This President's Tweeting Is Squandering Our Time       POLITICS
# 1     2              Protecting America From Its President       POLITICS
# 2     3  We’re Still, Somehow, A Year Away From The Pre...       POLITICS
# 3     4  Obama Has Some Issues With How The Media Are C...       POLITICS
# 4     5  8 Problems You May Encounter Going To Vote In ...  HOME & LIVING
# 5     6  True Patriotism Requires Supporting Every Pres...       POLITICS
# 6     7  Shonda Rhimes Says 2016 Election Is Mirroring ...       POLITICS
# 7     8  Lying To The Press Is Nothing New For The Pres...       POLITICS
# 8     9  Are President Trump's Supporters Embarrassed T...       POLITICS
# 9    10  President Obama Hawaii: What To Do On Oahu (PH...         TRAVEL
#
#    Similarity Score
# 0             0.490
# 1             0.487
# 2             0.377
# 3             0.354
# 4             0.342
# 5             0.315
# 6             0.309
# 7             0.305
# 8             0.302
# 9             0.294
