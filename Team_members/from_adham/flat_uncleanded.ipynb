# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# # Read Csv file

# %%
df = pd.read_csv('surat_uncleaned.csv')

# %%
df
# Out:
#                                           property_name areaWithType  \
# 0             2 BHK Apartment for Sale in Dindoli Surat  Carpet Area
# 1              2 BHK Apartment for Sale in Althan Surat   Super Area
# 2             2 BHK Apartment for Sale in Pal Gam Surat   Super Area
# 3        2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area
# 4     2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area
# ...                                                 ...          ...
# 4520  6 BHK Apartment for Sale in Millionaires Lifes...  Carpet Area
# 4521  4 BHK Apartment for Sale in Savan Superia, Alt...   Super Area
# 4522  5 BHK Apartment for Sale in Roongta Green Vall...  Carpet Area
# 4523  6 BHK Apartment for Sale in Cellestial Dreams,...  Carpet Area
# 4524  4 BHK Apartment for Sale in Roongta Green Vall...   Super Area
#
#      square_feet      transaction            status        floor  \
# 0       644 sqft     New Property  Poss. by Oct '24  5 out of 10
# 1      1278 sqft     New Property  Poss. by Jan '26  6 out of 14
# 2      1173 sqft           Resale     Ready to Move  5 out of 13
# 3       700 sqft     New Property     Ready to Move  6 out of 14
# 4      1250 sqft  Orchid Fantasia      New Property  Unfurnished
# ...          ...              ...               ...          ...
# 4520   2000 sqft     New Property  Poss. by Dec '26  5 out of 12
# 4521   3600 sqft     New Property  Poss. by Dec '25  5 out of 16
# 4522   2250 sqft     New Property  Poss. by Dec '25  7 out of 13
# 4523   3450 sqft     New Property     Ready to Move  7 out of 18
# 4524   4500 sqft     New Property     Ready to Move  3 out of 12
#
#           furnishing        facing  \
# 0        Unfurnished          West
# 1        Unfurnished   South -West
# 2     Semi-Furnished          East
# 3        Unfurnished          East
# 4                  2             2
# ...              ...           ...
# 4520     Unfurnished  South - East
# 4521     Unfurnished  South - East
# 4522     Unfurnished  North - East
# 4523     Unfurnished  North - West
# 4524     Unfurnished         North
#
#                                             description    price_per_sqft  \
# 0     Luxury project with basement parking, Solar ro...  ₹2,891 per sqft
# 1     2 And 3 BHK Luxurious Flat for Sell In New Alt...  ₹3,551 per sqft
# 2     This affordable 2 BHK flat is situated along a...  ₹3,800 per sqft
# 3     2 BHK Flat For sell IN Jahangirabad Prime Loca...  ₹3,966 per sqft
# 4     Multistorey Apartment for Sale in Palanpur, Su...  ₹3,600 per sqft
# ...                                                 ...               ...
# 4520  Check out Millionaires Lifestyle in Vesu, one ...               NaN
# 4521  Superia is a premium residential project launc...               NaN
# 4522  When it comes to beautiful homes, nothing beat...               NaN
# 4523  DRB Ravani Cellestial Dreams in Vesu, Surat is...               NaN
# 4524  Roongta Green Valley is one of the popular res...               NaN
#
#                price
# 0         ₹33.8 Lac
# 1         ₹45.4 Lac
# 2         ₹44.6 Lac
# 3           ₹47 Lac
# 4           ₹45 Lac
# ...              ...
# 4520  Call for Price
# 4521  Call for Price
# 4522  Call for Price
# 4523  Call for Price
# 4524  Call for Price
#
# [4525 rows x 11 columns]

# %% [markdown]
# ## Look at the data

# %%
print("Data Shape:", df.shape)
# Out:
# Data Shape: (4525, 11)

# %%
print("Data Types:", df.dtypes)
# Out:
# Data Types: property_name     object
# areaWithType      object
# square_feet       object
# transaction       object
# status            object
# floor             object
# furnishing        object
# facing            object
# description       object
# price_per_sqft    object
# price             object
# dtype: object

# %%
print("Missing Values:", df.isnull().sum())
# Out:
# Missing Values: property_name        0
# areaWithType         0
# square_feet          0
# transaction        104
# status               1
# floor               45
# furnishing         340
# facing             589
# description       1371
# price_per_sqft     368
# price                0
# dtype: int64

# %% [markdown]
# # PREPROCCESSING

# %%
def price_to_inr(x):
    if pd.isna(x): 
        return np.nan
    s = str(x).lower().replace('₹','').replace(',','').strip()
    if 'request' in s or 'call' in s:   # ignore "on request", "call for price"
        return np.nan

    total = 0.0
    # find numbers with optional unit after them
    for num, unit in re.findall(r'(\d+(?:\.\d+)?)\s*(cr|crore|lac|lakh)?', s):
        n = float(num)
        if unit in ('cr','crore'): n *= 1e7
        elif unit in ('lac','lakh'): n *= 1e5
        total += n

    if total > 0: 
        return total
    # no unit words: try plain number like "5500000"
    try: 
        return float(s)
    except:
        return np.nan

# %%
df['price_num'] = df['price'].apply(price_to_inr)

# %%
df
# Out:
#                                           property_name areaWithType  \
# 0             2 BHK Apartment for Sale in Dindoli Surat  Carpet Area
# 1              2 BHK Apartment for Sale in Althan Surat   Super Area
# 2             2 BHK Apartment for Sale in Pal Gam Surat   Super Area
# 3        2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area
# 4     2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area
# ...                                                 ...          ...
# 4520  6 BHK Apartment for Sale in Millionaires Lifes...  Carpet Area
# 4521  4 BHK Apartment for Sale in Savan Superia, Alt...   Super Area
# 4522  5 BHK Apartment for Sale in Roongta Green Vall...  Carpet Area
# 4523  6 BHK Apartment for Sale in Cellestial Dreams,...  Carpet Area
# 4524  4 BHK Apartment for Sale in Roongta Green Vall...   Super Area
#
#      square_feet      transaction            status        floor  \
# 0       644 sqft     New Property  Poss. by Oct '24  5 out of 10
# 1      1278 sqft     New Property  Poss. by Jan '26  6 out of 14
# 2      1173 sqft           Resale     Ready to Move  5 out of 13
# 3       700 sqft     New Property     Ready to Move  6 out of 14
# 4      1250 sqft  Orchid Fantasia      New Property  Unfurnished
# ...          ...              ...               ...          ...
# 4520   2000 sqft     New Property  Poss. by Dec '26  5 out of 12
# 4521   3600 sqft     New Property  Poss. by Dec '25  5 out of 16
# 4522   2250 sqft     New Property  Poss. by Dec '25  7 out of 13
# 4523   3450 sqft     New Property     Ready to Move  7 out of 18
# 4524   4500 sqft     New Property     Ready to Move  3 out of 12
#
#           furnishing        facing  \
# 0        Unfurnished          West
# 1        Unfurnished   South -West
# 2     Semi-Furnished          East
# 3        Unfurnished          East
# 4                  2             2
# ...              ...           ...
# 4520     Unfurnished  South - East
# 4521     Unfurnished  South - East
# 4522     Unfurnished  North - East
# 4523     Unfurnished  North - West
# 4524     Unfurnished         North
#
#                                             description    price_per_sqft  \
# 0     Luxury project with basement parking, Solar ro...  ₹2,891 per sqft
# 1     2 And 3 BHK Luxurious Flat for Sell In New Alt...  ₹3,551 per sqft
# 2     This affordable 2 BHK flat is situated along a...  ₹3,800 per sqft
# 3     2 BHK Flat For sell IN Jahangirabad Prime Loca...  ₹3,966 per sqft
# 4     Multistorey Apartment for Sale in Palanpur, Su...  ₹3,600 per sqft
# ...                                                 ...               ...
# 4520  Check out Millionaires Lifestyle in Vesu, one ...               NaN
# 4521  Superia is a premium residential project launc...               NaN
# 4522  When it comes to beautiful homes, nothing beat...               NaN
# 4523  DRB Ravani Cellestial Dreams in Vesu, Surat is...               NaN
# 4524  Roongta Green Valley is one of the popular res...               NaN
#
#                price  price_num
# 0         ₹33.8 Lac   3380000.0
# 1         ₹45.4 Lac   4540000.0
# 2         ₹44.6 Lac   4460000.0
# 3           ₹47 Lac   4700000.0
# 4           ₹45 Lac   4500000.0
# ...              ...        ...
# 4520  Call for Price        NaN
# 4521  Call for Price        NaN
# 4522  Call for Price        NaN
# 4523  Call for Price        NaN
# 4524  Call for Price        NaN
#
# [4525 rows x 12 columns]

# %%
def normalize_furnishing(x):
    if pd.isna(x): return np.nan
    t = str(x).strip().lower()
    mapping = {
        "semifurnished":"semi-furnished", "semi furnished":"semi-furnished",
        "semi-furnished":"semi-furnished",
        "fully furnished":"furnished", "full furnished":"furnished", "furnished":"furnished",
        "unfurnished":"unfurnished", "not furnished":"unfurnished", "raw":"unfurnished"
    }
    return mapping.get(t, t)

# %%
def normalize_facing(x):
    if pd.isna(x): return np.nan
    t = str(x).strip().lower()
    m = {
        "e":"east","east":"east","w":"west","west":"west",
        "n":"north","north":"north","s":"south","south":"south",
        "ne":"northeast","north-east":"northeast","north east":"northeast",
        "nw":"northwest","north-west":"northwest","north west":"northwest",
        "se":"southeast","south-east":"southeast","south east":"southeast",
        "sw":"southwest","south-west":"southwest","south west":"southwest",
    }
    return m.get(t, t)

# %%
NUM = re.compile(r'[\d,.]+')

def num_from_text(x):
    """First numeric token -> float (handles commas)."""
    if pd.isna(x): return np.nan
    m = NUM.search(str(x))
    return float(m.group(0).replace(",", "")) if m else np.nan

# %%
def normalize_floor(x):
    if pd.isna(x): return np.nan
    s = str(x).lower().strip()
    if "basement" in s: return -1
    if s == "g" or "ground" in s: return 0
    m = re.search(r"(\d+)", s)
    return int(m.group(1)) if m else np.nan

# %% [markdown]
# ## text tiding

# %%
for c in df.select_dtypes(include="object").columns:
    df[c] = df[c].astype(str).str.strip().replace({"nan": np.nan})

# %%
print("Cleaning numeric fields...")
df["square_feet_num"]    = df["square_feet"].apply(num_from_text)
df["price_num"]          = df["price"].apply(price_to_inr)
df["price_per_sqft_num"] = df["price_per_sqft"].apply(num_from_text)
# Out:
# Cleaning numeric fields...

# %%
print("Deriving missing price/per-sqft where possible...")
mask_pps = df["price_per_sqft_num"].isna() & df["price_num"].notna() & df["square_feet_num"].gt(0)
df.loc[mask_pps, "price_per_sqft_num"] = (df.loc[mask_pps, "price_num"] / df.loc[mask_pps, "square_feet_num"]).round(2)

mask_price = df["price_num"].isna() & df["price_per_sqft_num"].notna() & df["square_feet_num"].gt(0)
df.loc[mask_price, "price_num"] = (df.loc[mask_price, "price_per_sqft_num"] * df.loc[mask_price, "square_feet_num"]).round(0)
# Out:
# Deriving missing price/per-sqft where possible...

# %%
df
# Out:
#                                           property_name areaWithType  \
# 0             2 BHK Apartment for Sale in Dindoli Surat  Carpet Area
# 1              2 BHK Apartment for Sale in Althan Surat   Super Area
# 2             2 BHK Apartment for Sale in Pal Gam Surat   Super Area
# 3        2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area
# 4     2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area
# ...                                                 ...          ...
# 4520  6 BHK Apartment for Sale in Millionaires Lifes...  Carpet Area
# 4521  4 BHK Apartment for Sale in Savan Superia, Alt...   Super Area
# 4522  5 BHK Apartment for Sale in Roongta Green Vall...  Carpet Area
# 4523  6 BHK Apartment for Sale in Cellestial Dreams,...  Carpet Area
# 4524  4 BHK Apartment for Sale in Roongta Green Vall...   Super Area
#
#      square_feet      transaction            status        floor  \
# 0       644 sqft     New Property  Poss. by Oct '24  5 out of 10
# 1      1278 sqft     New Property  Poss. by Jan '26  6 out of 14
# 2      1173 sqft           Resale     Ready to Move  5 out of 13
# 3       700 sqft     New Property     Ready to Move  6 out of 14
# 4      1250 sqft  Orchid Fantasia      New Property  Unfurnished
# ...          ...              ...               ...          ...
# 4520   2000 sqft     New Property  Poss. by Dec '26  5 out of 12
# 4521   3600 sqft     New Property  Poss. by Dec '25  5 out of 16
# 4522   2250 sqft     New Property  Poss. by Dec '25  7 out of 13
# 4523   3450 sqft     New Property     Ready to Move  7 out of 18
# 4524   4500 sqft     New Property     Ready to Move  3 out of 12
#
#           furnishing        facing  \
# 0        Unfurnished          West
# 1        Unfurnished   South -West
# 2     Semi-Furnished          East
# 3        Unfurnished          East
# 4                  2             2
# ...              ...           ...
# 4520     Unfurnished  South - East
# 4521     Unfurnished  South - East
# 4522     Unfurnished  North - East
# 4523     Unfurnished  North - West
# 4524     Unfurnished         North
#
#                                             description   price_per_sqft  \
# 0     Luxury project with basement parking, Solar ro...  ₹2,891 per sqft
# 1     2 And 3 BHK Luxurious Flat for Sell In New Alt...  ₹3,551 per sqft
# 2     This affordable 2 BHK flat is situated along a...  ₹3,800 per sqft
# 3     2 BHK Flat For sell IN Jahangirabad Prime Loca...  ₹3,966 per sqft
# 4     Multistorey Apartment for Sale in Palanpur, Su...  ₹3,600 per sqft
# ...                                                 ...              ...
# 4520  Check out Millionaires Lifestyle in Vesu, one ...              NaN
# 4521  Superia is a premium residential project launc...              NaN
# 4522  When it comes to beautiful homes, nothing beat...              NaN
# 4523  DRB Ravani Cellestial Dreams in Vesu, Surat is...              NaN
# 4524  Roongta Green Valley is one of the popular res...              NaN
#
#                price  price_num  square_feet_num  price_per_sqft_num
# 0          ₹33.8 Lac  3380000.0            644.0              2891.0
# 1          ₹45.4 Lac  4540000.0           1278.0              3551.0
# 2          ₹44.6 Lac  4460000.0           1173.0              3800.0
# 3            ₹47 Lac  4700000.0            700.0              3966.0
# 4            ₹45 Lac  4500000.0           1250.0              3600.0
# ...              ...        ...              ...                 ...
# 4520  Call for Price        NaN           2000.0                 NaN
# 4521  Call for Price        NaN           3600.0                 NaN
# 4522  Call for Price        NaN           2250.0                 NaN
# 4523  Call for Price        NaN           3450.0                 NaN
# 4524  Call for Price        NaN           4500.0                 NaN
#
# [4525 rows x 14 columns]

# %%
print("Normalizing categories...")
if "furnishing" in df: df["furnishing"] = df["furnishing"].apply(normalize_furnishing)
if "facing" in df:     df["facing"]     = df["facing"].apply(normalize_facing)
if "floor" in df:      df["floor_num"]  = df["floor"].apply(normalize_floor)

# Simple tidy on a few others
if "transaction" in df: df["transaction"] = df["transaction"].astype(str).str.lower().str.strip()
if "status" in df:      df["status"]      = df["status"].astype(str).str.lower().str.strip()
if "areaWithType" in df: df["areaWithType"] = df["areaWithType"].astype(str).str.title()
if "property_name" in df: df["property_name"] = df["property_name"].astype(str).str.title()
# Out:
# Normalizing categories...

# %% [markdown]
# # Fill mising values

# %%
print("Imputing missing values (median for numeric, mode for categorical)...")
for c in ["square_feet_num","price_num","price_per_sqft_num","floor_num"]:
    if c in df:
        df[c] = df[c].fillna(df[c].median())

for c in ["transaction","status","furnishing","facing"]:
    if c in df:
        mode = df[c].mode(dropna=True)
        if len(mode): df[c] = df[c].fillna(mode.iloc[0])
# Out:
# Imputing missing values (median for numeric, mode for categorical)...

# %% [markdown]
# # Remove Duplicates

# %%
key_cols = [c for c in ["property_name","areaWithType","square_feet_num","price_num"] if c in df]
before = len(df)
df = df.drop_duplicates(subset=key_cols, keep="first").reset_index(drop=True)
after = len(df)
print(f"Duplicates removed: {before - after}")
# Out:
# Duplicates removed: 282

# %%
order = [
    "property_name","areaWithType",
    "square_feet","square_feet_num",
    "transaction","status",
    "floor","floor_num","furnishing","facing",
    "description",
    "price_per_sqft","price_per_sqft_num",
    "price","price_num"
]
df = df[[c for c in order if c in df.columns]]

# %%
df
# Out:
#                                           property_name areaWithType  \
# 0             2 Bhk Apartment For Sale In Dindoli Surat  Carpet Area
# 1              2 Bhk Apartment For Sale In Althan Surat   Super Area
# 2             2 Bhk Apartment For Sale In Pal Gam Surat   Super Area
# 3        2 Bhk Apartment For Sale In Jahangirabad Surat  Carpet Area
# 4     2 Bhk Apartment For Sale In Orchid Fantasia, P...   Super Area
# ...                                                 ...          ...
# 4238  6 Bhk Apartment For Sale In Millionaires Lifes...  Carpet Area
# 4239  4 Bhk Apartment For Sale In Savan Superia, Alt...   Super Area
# 4240  5 Bhk Apartment For Sale In Roongta Green Vall...  Carpet Area
# 4241  6 Bhk Apartment For Sale In Cellestial Dreams,...  Carpet Area
# 4242  4 Bhk Apartment For Sale In Roongta Green Vall...   Super Area
#
#      square_feet  square_feet_num      transaction            status  \
# 0       644 sqft            644.0     new property  poss. by oct '24
# 1      1278 sqft           1278.0     new property  poss. by jan '26
# 2      1173 sqft           1173.0           resale     ready to move
# 3       700 sqft            700.0     new property     ready to move
# 4      1250 sqft           1250.0  orchid fantasia      new property
# ...          ...              ...              ...               ...
# 4238   2000 sqft           2000.0     new property  poss. by dec '26
# 4239   3600 sqft           3600.0     new property  poss. by dec '25
# 4240   2250 sqft           2250.0     new property  poss. by dec '25
# 4241   3450 sqft           3450.0     new property     ready to move
# 4242   4500 sqft           4500.0     new property     ready to move
#
#             floor  floor_num      furnishing        facing  \
# 0     5 out of 10        5.0     unfurnished          west
# 1     6 out of 14        6.0     unfurnished   south -west
# 2     5 out of 13        5.0  semi-furnished          east
# 3     6 out of 14        6.0     unfurnished          east
# 4     Unfurnished        5.0               2             2
# ...           ...        ...             ...           ...
# 4238  5 out of 12        5.0     unfurnished  south - east
# 4239  5 out of 16        5.0     unfurnished  south - east
# 4240  7 out of 13        7.0     unfurnished  north - east
# 4241  7 out of 18        7.0     unfurnished  north - west
# 4242  3 out of 12        3.0     unfurnished         north
#
#                                             description   price_per_sqft  \
# 0     Luxury project with basement parking, Solar ro...  ₹2,891 per sqft
# 1     2 And 3 BHK Luxurious Flat for Sell In New Alt...  ₹3,551 per sqft
# 2     This affordable 2 BHK flat is situated along a...  ₹3,800 per sqft
# 3     2 BHK Flat For sell IN Jahangirabad Prime Loca...  ₹3,966 per sqft
# 4     Multistorey Apartment for Sale in Palanpur, Su...  ₹3,600 per sqft
# ...                                                 ...              ...
# 4238  Check out Millionaires Lifestyle in Vesu, one ...              NaN
# 4239  Superia is a premium residential project launc...              NaN
# 4240  When it comes to beautiful homes, nothing beat...              NaN
# 4241  DRB Ravani Cellestial Dreams in Vesu, Surat is...              NaN
# 4242  Roongta Green Valley is one of the popular res...              NaN
#
#       price_per_sqft_num           price  price_num
# 0                 2891.0       ₹33.8 Lac  3380000.0
# 1                 3551.0       ₹45.4 Lac  4540000.0
# 2                 3800.0       ₹44.6 Lac  4460000.0
# 3                 3966.0         ₹47 Lac  4700000.0
# 4                 3600.0         ₹45 Lac  4500000.0
# ...                  ...             ...        ...
# 4238              4690.0  Call for Price  7100000.0
# 4239              4690.0  Call for Price  7100000.0
# 4240              4690.0  Call for Price  7100000.0
# 4241              4690.0  Call for Price  7100000.0
# 4242              4690.0  Call for Price  7100000.0
#
# [4243 rows x 15 columns]

# %%
print("\n=== SUMMARY ===")
print("Shape:", df.shape)
print("Nulls after cleaning:\n", df.isna().sum())
print("Price per sqft (min/mean/max):", df["price_per_sqft_num"].min(), df["price_per_sqft_num"].mean(), df["price_per_sqft_num"].max())
print("Price (min/mean/max):", df["price_num"].min(), df["price_num"].mean(), df["price_num"].max())
# Out:
# === SUMMARY ===
# Shape: (4243, 10)
# Nulls after cleaning:
#  property_name         0
# areaWithType          0
# square_feet_num       0
# transaction           0
# status                0
# floor_num             0
# furnishing            0
# facing                0
# price_per_sqft_num    0
# price_num             0
# dtype: int64
# Price per sqft (min/mean/max): 1.0 10004.86283290125 12500000.0
# Price (min/mean/max): 100000.0 13069686.542540655 5344400000.000001

# %%
df.drop(columns=['description'], inplace=True)

# %%
df.dtypes
# Out:
# property_name          object
# areaWithType           object
# square_feet_num       float64
# transaction            object
# status                 object
# floor_num             float64
# furnishing             object
# facing                 object
# price_per_sqft_num    float64
# price_num             float64
# dtype: object

# %%
df.drop(columns=['square_feet'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df.drop(columns=['square_feet'], inplace=True)
#
# File c:\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# File c:\Python313\Lib\site-packages\pandas\core\generic.py:4807, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4805 for axis, labels in axes.items():
#    4806     if labels is not None:
# -> 4807         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4809 if inplace:
#    4810     self._update_inplace(obj)
#
# File c:\Python313\Lib\site-packages\pandas\core\generic.py:4849, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4847         new_axis = axis.drop(labels, level=level, errors=errors)
#    4848     else:
# -> 4849         new_axis = axis.drop(labels, errors=errors)
#    4850     indexer = axis.get_indexer(new_axis)
#    4852 # Case for non-unique axis
#    4853 else:
#
# File c:\Python313\Lib\site-packages\pandas\core\indexes\base.py:7098, in Index.drop(self, labels, errors)
#    7096 if mask.any():
#    7097     if errors != "ignore":
# -> 7098         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7099     indexer = indexer[~mask]
#    7100 return self.delete(indexer)
#
# KeyError: "['square_feet'] not found in axis"

# %%
df.drop(columns=['price_per_sqft'], inplace=True)

# %%
df.drop(columns=['price'], inplace=True)

# %%
df.drop(columns=['floor'], inplace=True)
