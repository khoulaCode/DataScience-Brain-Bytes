# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = r"data\laptopData (1).csv"
df = pd.read_csv(path)
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# ## Data Exploration

# %%
df.head()   #get the first 5 rows
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.head(50)  #get the first 50 rows
# Out:
#     Unnamed: 0 Company            TypeName Inches  \
# 0          0.0   Apple           Ultrabook   13.3
# 1          1.0   Apple           Ultrabook   13.3
# 2          2.0      HP            Notebook   15.6
# 3          3.0   Apple           Ultrabook   15.4
# 4          4.0   Apple           Ultrabook   13.3
# 5          5.0    Acer            Notebook   15.6
# 6          6.0   Apple           Ultrabook   15.4
# 7          7.0   Apple           Ultrabook   13.3
# 8          8.0    Asus           Ultrabook     14
# 9          9.0    Acer           Ultrabook     14
# 10        10.0      HP            Notebook   15.6
# 11        11.0      HP            Notebook   15.6
# 12        12.0   Apple           Ultrabook   15.4
# 13        13.0    Dell            Notebook   15.6
# 14        14.0   Apple           Ultrabook     12
# 15        15.0   Apple           Ultrabook   13.3
# 16        16.0    Dell            Notebook   15.6
# 17        17.0   Apple           Ultrabook   15.4
# ...

# %%
df.tail() # get the last 5 rows
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# ...

# %%
df.info()  #Check column names, data types, and non-null counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1273 non-null   object
#  3   Inches            1273 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1273 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1273 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
df.describe()  # to  get quick summary statistics of all numeric columns in your DataFrame.
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000

# %%
df.columns = df.columns.str.strip #s used to clean your column names by removing any leading or trailing spaces.

# %%
df.columns #  to see all the column names in your DataFrame as an Index object.
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df.index #to  shows  the row labels (the index) of the DataFrame.
# Out:
# RangeIndex(start=0, stop=1303, step=1)

# %%
df[["Company", "TypeName", "Inches", "ScreenResolution","Cpu", "Ram", "Memory", "Gpu", "OpSys", "Weight"]].describe() #Categorical/object columns -->it gives count, unique, top, freq.
# Out:
#        Company  TypeName Inches   ScreenResolution  \
# count     1273      1273   1273               1273
# unique      19         6     25                 40
# top     Lenovo  Notebook   15.6  Full HD 1920x1080
# freq       290       710    640                495
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1273  1273       1273                   1273
# unique                         118    10         40                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           183   601        401                    271
#
#              OpSys Weight
# count         1273   1273
# unique           9    189
# top     Windows 10  2.2kg
# freq          1047    111

# %%
df.dtypes #to know the data types
# Out:
# Unnamed: 0          float64
# Company              object
# TypeName             object
# Inches               object
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
df.Company.unique() # to show a list of all unique values in the Company column
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', nan, 'Chuwi',
#        'MSI', 'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
df.TypeName .unique() # a list of all unique values in theType name column
# Out:
# array(['Ultrabook', 'Notebook', nan, 'Gaming', '2 in 1 Convertible',
#        'Workstation', 'Netbook'], dtype=object)

# %%
df.TypeName.value_counts() #t counts how many times each unique value appears in the TypeName column
# Out:
# TypeName
# Notebook              710
# Gaming                203
# Ultrabook             191
# 2 in 1 Convertible    116
# Workstation            29
# Netbook                24
# Name: count, dtype: int64

# %%
df.Company.value_counts().plot.bar(color = 'skyblue')
# Out:
# <Axes: xlabel='Company'>

# %%
df['Price']<20
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Price, Length: 1303, dtype: bool

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.isnull().sum()  # to know how many null values
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
df_process = df.drop('Unnamed: 0',axis = 1)   # it deletes the column that have the null values
df_process
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook     14
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_process.isnull().sum()
# Out:
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df_process.head(50)
# Out:
#    Company            TypeName Inches  \
# 0    Apple           Ultrabook   13.3
# 1    Apple           Ultrabook   13.3
# 2       HP            Notebook   15.6
# 3    Apple           Ultrabook   15.4
# 4    Apple           Ultrabook   13.3
# 5     Acer            Notebook   15.6
# 6    Apple           Ultrabook   15.4
# 7    Apple           Ultrabook   13.3
# 8     Asus           Ultrabook     14
# 9     Acer           Ultrabook     14
# 10      HP            Notebook   15.6
# 11      HP            Notebook   15.6
# 12   Apple           Ultrabook   15.4
# 13    Dell            Notebook   15.6
# 14   Apple           Ultrabook     12
# 15   Apple           Ultrabook   13.3
# 16    Dell            Notebook   15.6
# 17   Apple           Ultrabook   15.4
# 18  Lenovo            Notebook   15.6
# 19    Dell           Ultrabook   13.3
# 20     NaN                 NaN    NaN
# 21  Lenovo              Gaming   15.6
# 22      HP            Notebook   15.6
# ...

# %%
df_process.dropna(how = 'all', inplace = True)  # to drop the rows that have nan 
df_process
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook     14
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_process.isnull().sum()  # to check the null values after drop
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df_process.tail(50)
# Out:
#      Company            TypeName Inches  \
# 1253  Lenovo            Notebook     14
# 1254    Dell            Notebook   15.6
# 1255    Asus            Notebook   15.6
# 1256    Asus              Gaming   17.3
# 1257    Dell            Notebook   15.6
# 1258  Lenovo            Notebook   15.6
# 1259     MSI              Gaming   15.6
# 1260  Lenovo  2 in 1 Convertible     14
# 1261    Asus           Ultrabook   13.3
# 1262    Dell            Notebook   15.6
# 1263    Acer            Notebook   15.6
# 1264    Dell            Notebook   15.6
# 1265  Lenovo            Notebook   15.6
# 1266      HP            Notebook   15.6
# 1267    Dell            Notebook   15.6
# 1268      HP             Netbook   11.6
# 1269    Asus            Notebook   15.6
# 1270  Lenovo  2 in 1 Convertible     14
# 1271  Lenovo  2 in 1 Convertible   13.3
# 1272  Lenovo            Notebook     14
# 1273      HP            Notebook   15.6
# 1274    Asus            Notebook   15.6
# ...

# %%
df_process = df_process.reset_index(drop=True)  #-->reset the index to make it sequential..using drop means it will remove the old index instead of adding it as a new column.
df_process
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1268  Lenovo  2 in 1 Convertible     14
# 1269  Lenovo  2 in 1 Convertible   13.3
# 1270  Lenovo            Notebook     14
# 1271      HP            Notebook   15.6
# 1272    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1268   IPS Panel Full HD / Touchscreen 1920x1080
# 1269  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_process.head(50)
# Out:
#    Company            TypeName Inches  \
# 0    Apple           Ultrabook   13.3
# 1    Apple           Ultrabook   13.3
# 2       HP            Notebook   15.6
# 3    Apple           Ultrabook   15.4
# 4    Apple           Ultrabook   13.3
# 5     Acer            Notebook   15.6
# 6    Apple           Ultrabook   15.4
# 7    Apple           Ultrabook   13.3
# 8     Asus           Ultrabook     14
# 9     Acer           Ultrabook     14
# 10      HP            Notebook   15.6
# 11      HP            Notebook   15.6
# 12   Apple           Ultrabook   15.4
# 13    Dell            Notebook   15.6
# 14   Apple           Ultrabook     12
# 15   Apple           Ultrabook   13.3
# 16    Dell            Notebook   15.6
# 17   Apple           Ultrabook   15.4
# 18  Lenovo            Notebook   15.6
# 19    Dell           Ultrabook   13.3
# 20  Lenovo              Gaming   15.6
# 21      HP            Notebook   15.6
# 22    Dell  2 in 1 Convertible   13.3
# ...

# %%
df_process.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1268     True
# 1269     True
# 1270     True
# 1271     True
# 1272     True
# Length: 1273, dtype: bool

# %%
df_process.duplicated().sum()
# Out:
# np.int64(29)

# %%
# Count all duplicate rows
duplicates = df_process.value_counts().reset_index(name='count')
duplicates
# Out:
#       Company   TypeName Inches                 ScreenResolution  \
# 0        Asus   Notebook   15.6                         1366x768
# 1        Asus  Ultrabook   13.3      IPS Panel Full HD 1920x1080
# 2        Dell   Notebook   15.6                         1366x768
# 3        Dell   Notebook   15.6                         1366x768
# 4        Acer   Notebook   15.6                         1366x768
# ...       ...        ...    ...                              ...
# 1239  Toshiba   Notebook   15.6      IPS Panel Full HD 1920x1080
# 1240  Toshiba  Ultrabook   12.5  Full HD / Touchscreen 1920x1080
# 1241  Toshiba  Ultrabook   13.3                         1366x768
# 1242  Toshiba  Ultrabook   13.3  Full HD / Touchscreen 1920x1080
# 1243  Toshiba  Ultrabook   13.3  Full HD / Touchscreen 1920x1080
#
#                                        Cpu   Ram     Memory  \
# 0     Intel Celeron Dual Core N3050 1.6GHz   4GB  500GB HDD
# 1                 Intel Core M 6Y30 0.9GHz   8GB  512GB SSD
# ...

# %%
df_process[df_process.duplicated()]
# Out:
#      Company            TypeName Inches  \
# 1244    Asus            Notebook   15.6
# 1245    Asus           Ultrabook   13.3
# 1246    Dell            Notebook   15.6
# 1247    Acer            Notebook   15.6
# 1248    Dell            Notebook   15.6
# 1249  Lenovo            Notebook   15.6
# 1250      HP            Notebook   15.6
# 1251    Dell            Notebook   15.6
# 1252      HP             Netbook   11.6
# 1253    Asus            Notebook   15.6
# 1254  Lenovo  2 in 1 Convertible     14
# 1255  Lenovo  2 in 1 Convertible   13.3
# 1256  Lenovo            Notebook     14
# 1257      HP            Notebook   15.6
# 1258    Asus            Notebook   15.6
# 1259    Asus           Ultrabook   13.3
# 1260    Dell            Notebook   15.6
# 1261    Acer            Notebook   15.6
# 1262    Dell            Notebook   15.6
# 1263  Lenovo            Notebook   15.6
# 1264      HP            Notebook   15.6
# 1265    Dell            Notebook   15.6
# ...

# %%
# Show only duplicate rows
duplicates = df_process[df_process.duplicated(keep=False)]
duplicates
# Out:
#      Company            TypeName Inches  \
# 1144    Asus            Notebook   15.6
# 1231    Asus           Ultrabook   13.3
# 1232    Dell            Notebook   15.6
# 1233    Acer            Notebook   15.6
# 1234    Dell            Notebook   15.6
# 1235  Lenovo            Notebook   15.6
# 1236      HP            Notebook   15.6
# 1237    Dell            Notebook   15.6
# 1238      HP             Netbook   11.6
# 1239    Asus            Notebook   15.6
# 1240  Lenovo  2 in 1 Convertible     14
# 1241  Lenovo  2 in 1 Convertible   13.3
# 1242  Lenovo            Notebook     14
# 1243      HP            Notebook   15.6
# 1244    Asus            Notebook   15.6
# 1245    Asus           Ultrabook   13.3
# 1246    Dell            Notebook   15.6
# 1247    Acer            Notebook   15.6
# 1248    Dell            Notebook   15.6
# 1249  Lenovo            Notebook   15.6
# 1250      HP            Notebook   15.6
# 1251    Dell            Notebook   15.6
# ...

# %%
duplicates.shape
# Out:
# (43, 11)

# %%
df_process.drop_duplicates(keep = 'first')  # to drop all duplicated rows and keep just the first
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1239    Asus            Notebook   15.6
# 1240  Lenovo  2 in 1 Convertible     14
# 1241  Lenovo  2 in 1 Convertible   13.3
# 1242  Lenovo            Notebook     14
# 1243      HP            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1239                                    1366x768
# 1240   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df_process.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 109.5+ KB

# %%
df_process.dtypes
# Out:
# Company              object
# TypeName             object
# Inches               object
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
df_process.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
# Replace '?' with NaN  --> if i did not replace it i will not be able to convert it
df_process['Inches'] = df_process['Inches'].replace('?', np.nan)

# %%
# Convert Inches to float
df_process['Inches'] = df_process['Inches'].astype(float)

# %%
df_process.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
df_process['Ram'] = df_process['Ram'].str.replace('GB', '').astype(int) # Clean Ram and convert to int

# %%
df_process['Weight'] = df_process['Weight'].replace('?', np.nan)

# %%
df_process['Weight'] = df_process['Weight'].str.replace('kg', '').astype(float )# Clean Weight and convert to float

# %%
df_process.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float64
# Price               float64
# dtype: object

# %%
df_process.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              1
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              1
# Price               0
# dtype: int64

# %%
df_process.head(50)
# Out:
#    Company            TypeName  Inches  \
# 0    Apple           Ultrabook    13.3
# 1    Apple           Ultrabook    13.3
# 2       HP            Notebook    15.6
# 3    Apple           Ultrabook    15.4
# 4    Apple           Ultrabook    13.3
# 5     Acer            Notebook    15.6
# 6    Apple           Ultrabook    15.4
# 7    Apple           Ultrabook    13.3
# 8     Asus           Ultrabook    14.0
# 9     Acer           Ultrabook    14.0
# 10      HP            Notebook    15.6
# 11      HP            Notebook    15.6
# 12   Apple           Ultrabook    15.4
# 13    Dell            Notebook    15.6
# 14   Apple           Ultrabook    12.0
# 15   Apple           Ultrabook    13.3
# 16    Dell            Notebook    15.6
# 17   Apple           Ultrabook    15.4
# 18  Lenovo            Notebook    15.6
# 19    Dell           Ultrabook    13.3
# 20  Lenovo              Gaming    15.6
# 21      HP            Notebook    15.6
# 22    Dell  2 in 1 Convertible    13.3
# ...

# %%
df_process[df_process['TypeName'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
df_process[df_process['Inches'].isnull()]   #to check if there is nan
# Out:
#     Company     TypeName  Inches   ScreenResolution  \
# 465    Dell  Workstation     NaN  Full HD 1920x1080
#
#                              Cpu  Ram     Memory                  Gpu  \
# 465  Intel Core i7 7700HQ 2.8GHz  8GB  256GB SSD  Nvidia Quadro M1200
#
#           OpSys  Weight      Price
# 465  Windows 10    1.78  128298.24

# %%
df_process[df_process['Weight'].isnull()]
# Out:
#     Company   TypeName  Inches   ScreenResolution                         Cpu  \
# 201    Dell  Ultrabook    13.3  Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
#
#      Ram     Memory                     Gpu       OpSys  Weight     Price
# 201  8GB  256GB SSD  Intel UHD Graphics 620  Windows 10     NaN  77202.72

# %%
# there is a relationship between Weight and Inches in laptops...
# In general, bigger screens (Inches) mean heavier laptops (Weight) because larger screens require bigger frames, batteries, and components

# %%
# Compute mean Inches for each Weight value
inches_by_weight = df_process.groupby('Weight')['Inches'].transform('mean')

# %%
# Fill missing Inches with the mean Inches for the same Weight
df_process['Inches'] = df_process['Inches'].fillna(inches_by_weight)

# %%
df_process[df_process['Inches'].isnull()]   #to check if there is null values
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
# Compute mean Weight for each Inches value
weight_by_inches = df_process.groupby('Inches')['Weight'].transform('mean')

# %%
# Fill missing Weight with the mean Weight for the same Inches
df_process['Weight'] = df_process['Weight'].fillna(weight_by_inches)

# %%
df_process[df_process['Weight'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
df_process
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1268  Lenovo  2 in 1 Convertible    14.0
# 1269  Lenovo  2 in 1 Convertible    13.3
# 1270  Lenovo            Notebook    14.0
# 1271      HP            Notebook    15.6
# 1272    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1268   IPS Panel Full HD / Touchscreen 1920x1080
# 1269  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_process.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df_process.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                   int64
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float64
# Price               float64
# dtype: object

# %%
df_process.loc[201] # to check the row that have nan --> just to check if it is filled or not (the weight)
# Out:
# Company                                   Dell
# TypeName                             Ultrabook
# Inches                                    13.3
# ScreenResolution             Full HD 1920x1080
# Cpu                 Intel Core i7 8550U 1.8GHz
# Ram                                        8GB
# Memory                               256GB SSD
# Gpu                     Intel UHD Graphics 620
# OpSys                               Windows 10
# Weight                                   1.346
# Price                                 77202.72
# Name: 201, dtype: object

# %%
df_process.loc[465] # to check the row that have nan --> just to check if it is filled or not (the Inches)
# Out:
# Company                                    Dell
# TypeName                            Workstation
# Inches                                     15.6
# ScreenResolution              Full HD 1920x1080
# Cpu                 Intel Core i7 7700HQ 2.8GHz
# Ram                                         8GB
# Memory                                256GB SSD
# Gpu                         Nvidia Quadro M1200
# OpSys                                Windows 10
# Weight                                     1.78
# Price                                 128298.24
# Name: 465, dtype: object

# %%
df_process['Inches']
# Out:
# 0       13.3
# 1       13.3
# 2       15.6
# 3       15.4
# 4       13.3
#         ...
# 1268    14.0
# 1269    13.3
# 1270    14.0
# 1271    15.6
# 1272    15.6
# Name: Inches, Length: 1273, dtype: float64

# %%
df_process[df_process['Inches'] == 13.3]
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 4      Apple           Ultrabook    13.3
# 7      Apple           Ultrabook    13.3
# 15     Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1241  Lenovo  2 in 1 Convertible    13.3
# 1245    Asus           Ultrabook    13.3
# 1255  Lenovo  2 in 1 Convertible    13.3
# 1259    Asus           Ultrabook    13.3
# 1269  Lenovo  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                         Cpu  \
# 0             IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 1                                       1440x900        Intel Core i5 1.8GHz
# 4             IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
# 7                                       1440x900        Intel Core i5 1.8GHz
# 15            IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# ...

# %%
df_process[df_process['Weight'] == 1.346]
# Out:
#     Company   TypeName  Inches   ScreenResolution                         Cpu  \
# 201    Dell  Ultrabook    13.3  Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
#
#      Ram     Memory                     Gpu       OpSys  Weight     Price
# 201  8GB  256GB SSD  Intel UHD Graphics 620  Windows 10   1.346  77202.72

# %%
df_process
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1268  Lenovo  2 in 1 Convertible    14.0
# 1269  Lenovo  2 in 1 Convertible    13.3
# 1270  Lenovo            Notebook    14.0
# 1271      HP            Notebook    15.6
# 1272    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1268   IPS Panel Full HD / Touchscreen 1920x1080
# 1269  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
plt.figure(figsize=(6,5))
plt.hist(df_process['Inches'], bins=15, color='lightblue', edgecolor='deeppink')
plt.title('Distribution of Screen Sizes')
plt.xlabel('Screen Size (Inches)',fontsize = 10 , color = 'darkmagenta')
plt.ylabel('Number of Laptops',fontsize = 10 , color = 'darkmagenta')
plt.grid(True, alpha = 0.4 , linestyle =":")
plt.show()

# %%
#Scatter plot  -->Screen Size vs Weight
plt.figure(figsize=(5,5))
plt.scatter(df_process['Inches'], df_process['Weight'], color='darkmagenta')
plt.xlabel('Screen Size (Inches)')
plt.ylabel('Weight (kg)')
plt.title('Screen Size vs Weight')
plt.show()

# %% [markdown]
# # calculation

# %%
#calculate the avg price per company

# %%
avg_company_price = df_process.groupby('Company')['Price'].mean()
avg_company_price
# Out:
# Company
# Acer          33394.615969
# Apple         83340.499886
# Asus          58972.373723
# Chuwi         16745.726400
# Dell          63237.061079
# Fujitsu       38574.720000
# Google        89386.080000
# HP            57214.371465
# Huawei        75870.720000
# LG           111834.720000
# Lenovo        58072.477208
# MSI           91814.548891
# Mediacom      15717.600000
# Microsoft     85903.788000
# Razer        178282.491429
# Samsung       75308.320000
# Toshiba       66747.370213
# Vero          11584.404000
# Xiaomi        60390.882000
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.bar(avg_company_price.index, avg_company_price.values, color=['Skyblue','Lightcoral', 'lightgreen','lightpink','purple'])
plt.title('Average Laptop Price by Company', fontsize = 16)
plt.xlabel('Company',fontsize = 14)
plt.ylabel('Average Price (€)',fontsize = 14)
plt.xticks(rotation=45)
plt.show()

# %%
max_Weight = df_process.groupby('TypeName')['Weight'].max()
print("Maximum Weight:\n",max_Weight)
# Out:
# Maximum Weight:
#  TypeName
# 2 in 1 Convertible     4.10
# Gaming                 4.70
# Netbook                2.40
# Notebook               8.23
# Ultrabook             11.10
# Workstation            3.42
# Name: Weight, dtype: float64

# %%
plt.figure(figsize=(6,6))
plt.bar(max_Weight.index, max_Weight.values, color=['Skyblue','Lightcoral', 'lightgreen','lightpink','purple'])
plt.title('Maximum Laptop weight', fontsize = 16)
plt.xlabel('Type Name',fontsize = 14)
plt.ylabel('Max weight(Kg)',fontsize = 14)
plt.xticks(rotation=40)
plt.grid(True, alpha = 0.6, linestyle = ":")
plt.show()
