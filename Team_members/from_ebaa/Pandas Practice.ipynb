# %%
import pandas as pd
import matplotlib

# %%
path ="C:/Users/bbuser/Desktop/DataScience/DataScience-Brain-Bytes/from_ebaa/data/Global Economy Indicators.csv"
data_f=pd.read_csv(path)
data_f
# Out:
#        CountryID        Country   Year   AMA exchange rate   \
# 0               4   Afghanistan    1970            0.044998
# 1               4   Afghanistan    1971            0.044998
# 2               4   Afghanistan    1972            0.044998
# 3               4   Afghanistan    1973            0.044998
# 4               4   Afghanistan    1974            0.044998
# ...           ...            ...    ...                 ...
# 10507         894        Zambia    2017            9.519501
# 10508         894        Zambia    2018           10.458143
# 10509         894        Zambia    2019           12.889418
# 10510         894        Zambia    2020           18.344093
# 10511         894        Zambia    2021           20.018487
#
#        IMF based exchange rate   Population   Currency   Per capita GNI   \
# 0                      0.044998     10752971   Afghani               164
# 1                      0.044998     11015857   Afghani               168
# ...

# %%
data_f.head() #Shows the first 5 rows of the DataF.
# Out:
#    CountryID        Country   Year   AMA exchange rate   \
# 0           4   Afghanistan    1970            0.044998
# 1           4   Afghanistan    1971            0.044998
# 2           4   Afghanistan    1972            0.044998
# 3           4   Afghanistan    1973            0.044998
# 4           4   Afghanistan    1974            0.044998
#
#    IMF based exchange rate   Population   Currency   Per capita GNI   \
# 0                  0.044998     10752971   Afghani               164
# 1                  0.044998     11015857   Afghani               168
# 2                  0.044998     11286753   Afghani               149
# 3                  0.044998     11575305   Afghani               150
# 4                  0.044998     11869879   Afghani               177
#
#    Agriculture, hunting, forestry, fishing (ISIC A-B)   \
# 0                                       8.699174e+08
# 1                                       9.108281e+08
# ...

# %%
data_f.tail() #Displays the last 5 rows of the DataF.
# Out:
#        CountryID   Country   Year   AMA exchange rate   \
# 10507         894   Zambia    2017            9.519501
# 10508         894   Zambia    2018           10.458143
# 10509         894   Zambia    2019           12.889418
# 10510         894   Zambia    2020           18.344093
# 10511         894   Zambia    2021           20.018487
#
#        IMF based exchange rate   Population  Currency   Per capita GNI   \
# 10507                  9.519501     17298054   Kwacha              1448
# 10508                 10.458143     17835893   Kwacha              1451
# 10509                 12.889418     18380477   Kwacha              1246
# 10510                 18.344093     18927715   Kwacha               928
# 10511                 20.018487     19473125   Kwacha              1062
#
#        Agriculture, hunting, forestry, fishing (ISIC A-B)   \
# 10507                                       1.041005e+09
# 10508                                       8.791160e+08
# ...

# %%
data_f.info() #Summarizes the column names, data types, and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10512 entries, 0 to 10511
# Data columns (total 26 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0    CountryID                                                                                  10512 non-null  int64
#  1    Country                                                                                    10512 non-null  object
#  2    Year                                                                                       10512 non-null  int64
#  3    AMA exchange rate                                                                          10512 non-null  float64
#  4    IMF based exchange rate                                                                    10512 non-null  float64
# ...

# %%
data_f.describe() #Summery ,, Returns statistical summary (mean, std, min, max, etc.) for numeric columns.
# Out:
#          CountryID          Year   AMA exchange rate   \
# count  10512.000000  10512.000000        1.051200e+04
# mean     431.116629   1996.262747        3.573959e+02
# std      251.169090     14.900361        2.291128e+03
# min        4.000000   1970.000000        4.300000e-14
# 25%      212.000000   1984.000000        1.000000e+00
# 50%      430.000000   1997.000000        2.812895e+00
# 75%      643.000000   2009.000000        5.134316e+01
# max      894.000000   2021.000000        1.116366e+05
#
#        IMF based exchange rate    Population   Per capita GNI   \
# count              1.051200e+04  1.051200e+04     10512.000000
# mean               3.419846e+02  2.851523e+07      8965.564593
# std                1.941857e+03  1.141296e+08     17070.205895
# min                4.300000e-14  4.359000e+03        34.000000
# 25%                1.000000e+00  6.330615e+05       730.000000
# 50%                2.761315e+00  5.051556e+06      2316.500000
# ...

# %%
data_f[[" Country "," Currency "]].describe() #Gives summary statistics (like count, unique, top, freq) for selected categorical columns.
# Out:
#              Country  Currency
# count           10512     10512
# unique            220       153
# top      Afghanistan      Euro
# freq               52      1108

# %%
data_f.nunique()
# Out:
# CountryID                                                                                      220
# Country                                                                                        220
# Year                                                                                            52
# AMA exchange rate                                                                             6414
# IMF based exchange rate                                                                       6251
# Population                                                                                   10498
# Currency                                                                                       153
# Per capita GNI                                                                                6479
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           10333
# ...

# %%
data_f.columns #Lists the column names of the DataF.
# Out:
# Index([' CountryID ', ' Country ', ' Year ', ' AMA exchange rate ',
#        ' IMF based exchange rate ', ' Population ', ' Currency ',
#        ' Per capita GNI ',
#        ' Agriculture, hunting, forestry, fishing (ISIC A-B) ',
#        ' Changes in inventories ', ' Construction (ISIC F) ',
#        ' Exports of goods and services ', ' Final consumption expenditure ',
#        ' General government final consumption expenditure ',
#        ' Gross capital formation ',
#        ' Gross fixed capital formation (including Acquisitions less disposals of valuables) ',
#        ' Household consumption expenditure (including Non-profit institutions serving households) ',
#        ' Imports of goods and services ', ' Manufacturing (ISIC D) ',
#        ' Mining, Manufacturing, Utilities (ISIC C-E) ',
#        ' Other Activities (ISIC J-P) ', ' Total Value Added ',
#        ' Transport, storage and communication (ISIC I) ',
# ...

# %%
data_f.index #Shows the row index range of the DataF.
# Out:
# RangeIndex(start=0, stop=10512, step=1)

# %%
data_f.dtypes #Displays the data type of each column
# Out:
# CountryID                                                                                      int64
# Country                                                                                       object
# Year                                                                                           int64
# AMA exchange rate                                                                            float64
# IMF based exchange rate                                                                      float64
# Population                                                                                     int64
# Currency                                                                                      object
# Per capita GNI                                                                                 int64
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           float64
# ...

# %%
data_f[' Country '].unique()
# Out:
# array([' Afghanistan ', ' Albania ', ' Algeria ', ' Andorra ', ' Angola ',
#        ' Antigua and Barbuda ', ' Azerbaijan ', ' Argentina ',
#        ' Australia ', ' Austria ', ' Bahamas ', ' Bahrain ',
#        ' Bangladesh ', ' Armenia ', ' Barbados ', ' Belgium ',
#        ' Bermuda ', ' Bhutan ', ' Bolivia (Plurinational State of) ',
#        ' Bosnia and Herzegovina ', ' Botswana ', ' Brazil ', ' Belize ',
#        ' Solomon Islands ', ' British Virgin Islands ',
#        ' Brunei Darussalam ', ' Bulgaria ', ' Myanmar ', ' Burundi ',
#        ' Belarus ', ' Cambodia ', ' Cameroon ', ' Canada ',
#        ' Cabo Verde ', ' Cayman Islands ', ' Central African Republic ',
#        ' Sri Lanka ', ' Chad ', ' Chile ', ' China ', ' Colombia ',
#        ' Comoros ', ' Congo ', ' D.R. of the Congo ', ' Cook Islands ',
#        ' Costa Rica ', ' Croatia ', ' Cuba ', ' Cyprus ',
#        ' Czechoslovakia (Former) ', ' Czechia ', ' Benin ', ' Denmark ',
# ...

# %%
data_f.nunique()
# Out:
# CountryID                                                                                      220
# Country                                                                                        220
# Year                                                                                            52
# AMA exchange rate                                                                             6414
# IMF based exchange rate                                                                       6251
# Population                                                                                   10498
# Currency                                                                                       153
# Per capita GNI                                                                                6479
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           10333
# ...

# %%
data_f.isnull
# Out:
# <bound method DataFrame.isnull of        CountryID        Country   Year   AMA exchange rate   \
# 0               4   Afghanistan    1970            0.044998
# 1               4   Afghanistan    1971            0.044998
# 2               4   Afghanistan    1972            0.044998
# 3               4   Afghanistan    1973            0.044998
# 4               4   Afghanistan    1974            0.044998
# ...           ...            ...    ...                 ...
# 10507         894        Zambia    2017            9.519501
# 10508         894        Zambia    2018           10.458143
# 10509         894        Zambia    2019           12.889418
# 10510         894        Zambia    2020           18.344093
# 10511         894        Zambia    2021           20.018487
#
#        IMF based exchange rate   Population   Currency   Per capita GNI   \
# 0                      0.044998     10752971   Afghani               164
# ...

# %%
data_f.isnull().sum()
# Out:
# CountryID                                                                                       0
# Country                                                                                         0
# Year                                                                                            0
# AMA exchange rate                                                                               0
# IMF based exchange rate                                                                         0
# Population                                                                                      0
# Currency                                                                                        0
# Per capita GNI                                                                                  0
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                            121
# Changes in inventories                                                                       1841
# ...

# %%
data_f.notnull().sum() #Shows the number of non-missing (valid) values per
# Out:
# CountryID                                                                                    10512
# Country                                                                                      10512
# Year                                                                                         10512
# AMA exchange rate                                                                            10512
# IMF based exchange rate                                                                      10512
# Population                                                                                   10512
# Currency                                                                                     10512
# Per capita GNI                                                                               10512
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           10391
# ...

# %%
data_f[' Population '].hist() #Plots a histogram for the charges column to show distribution.
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
data_f.boxplot() #Creates a boxplot for all numerical columns to detect outliers and spread.
# Out:
# <Axes: >
