# %% [markdown]
# ## Sales Performance Analysis with Walmart Data

# %%
import pandas as pd

# %%
store = pd.read_csv('data/stores.csv')
train = pd.read_csv('data/train.csv')
features = pd.read_csv('data/features.csv')

# %%
print(store.info())
print()
print(train.info())
print()
print(features.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
# ...

# %% [markdown]
# ### Total sales by store or department

# %%
sales = train.groupby('Dept')['Weekly_Sales'].sum()
sales
# Out:
# Dept
# 1     1.236388e+08
# 2     2.806112e+08
# 3     7.589245e+07
# 4     1.671467e+08
# 5     1.356074e+08
#           ...
# 95    4.493202e+08
# 96    7.383392e+07
# 97    8.949651e+07
# 98    3.982892e+07
# 99    3.581498e+05
# Name: Weekly_Sales, Length: 81, dtype: float64

# %% [markdown]
# ### Merging different datasets

# %%
merging = train.merge(store) 
merging
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size
# 0           1     1  2010-02-05      24924.50      False    A  151315
# 1           1     1  2010-02-12      46039.49       True    A  151315
# 2           1     1  2010-02-19      41595.55      False    A  151315
# 3           1     1  2010-02-26      19403.54      False    A  151315
# 4           1     1  2010-03-05      21827.90      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 421565     45    98  2012-09-28        508.37      False    B  118221
# 421566     45    98  2012-10-05        628.10      False    B  118221
# 421567     45    98  2012-10-12       1061.02      False    B  118221
# 421568     45    98  2012-10-19        760.01      False    B  118221
# 421569     45    98  2012-10-26       1076.80      False    B  118221
#
# [421570 rows x 7 columns]

# %%
pd.concat([features, train])
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1  2010-02-05        42.31       2.572        NaN        NaN
# 1           1  2010-02-12        38.51       2.548        NaN        NaN
# 2           1  2010-02-19        39.93       2.514        NaN        NaN
# 3           1  2010-02-26        46.63       2.561        NaN        NaN
# 4           1  2010-03-05        46.50       2.625        NaN        NaN
# ...       ...         ...          ...         ...        ...        ...
# 421565     45  2012-09-28          NaN         NaN        NaN        NaN
# 421566     45  2012-10-05          NaN         NaN        NaN        NaN
# 421567     45  2012-10-12          NaN         NaN        NaN        NaN
# 421568     45  2012-10-19          NaN         NaN        NaN        NaN
# 421569     45  2012-10-26          NaN         NaN        NaN        NaN
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# ...

# %%
train.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
store.value_counts()
# Out:
# Store  Type  Size
# 1      A     151315    1
# 2      A     202307    1
# 3      B     37392     1
# 4      A     205863    1
# 5      B     34875     1
# 6      A     202505    1
# 7      B     70713     1
# 8      A     155078    1
# 9      B     125833    1
# 10     B     126512    1
# 11     A     207499    1
# 12     B     112238    1
# 13     A     219622    1
# 14     A     200898    1
# 15     B     123737    1
# 16     B     57197     1
# 17     B     93188     1
# 18     B     120653    1
# 19     A     203819    1
# 20     A     203742    1
# 21     B     140167    1
# 22     B     119557    1
# 23     B     114533    1
# 24     A     203819    1
# 25     B     128107    1
# 26     A     152513    1
# 27     A     204184    1
# 28     A     206302    1
# 29     B     93638     1
# 30     C     42988     1
# 31     A     203750    1
# 32     A     203007    1
# 33     A     39690     1
# 34     A     158114    1
# 35     B     103681    1
# 36     A     39910     1
# ...

# %%
store_filter = store[store['Type'] == 'A']
store_filter
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 3       4    A  205863
# 5       6    A  202505
# 7       8    A  155078
# 10     11    A  207499
# 12     13    A  219622
# 13     14    A  200898
# 18     19    A  203819
# 19     20    A  203742
# 23     24    A  203819
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 35     36    A   39910
# 38     39    A  184109
# 39     40    A  155083
# 40     41    A  196321
