# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
df = pd.read_csv('data/Global Economy Indicators.csv')
df2 = pd.read_csv('data/world_population.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10512 entries, 0 to 10511
# Data columns (total 26 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0    CountryID                                                                                  10512 non-null  int64
#  1    Country                                                                                    10512 non-null  object
#  2    Year                                                                                       10512 non-null  int64
#  3    AMA exchange rate                                                                          10512 non-null  float64
#  4    IMF based exchange rate                                                                    10512 non-null  float64
# ...

# %%
df.head(3)
# Out:
#    CountryID        Country   Year   AMA exchange rate   \
# 0           4   Afghanistan    1970            0.044998
# 1           4   Afghanistan    1971            0.044998
# 2           4   Afghanistan    1972            0.044998
#
#    IMF based exchange rate   Population   Currency   Per capita GNI   \
# 0                  0.044998     10752971   Afghani               164
# 1                  0.044998     11015857   Afghani               168
# 2                  0.044998     11286753   Afghani               149
#
#    Agriculture, hunting, forestry, fishing (ISIC A-B)   \
# 0                                        869917407.0
# 1                                        910828104.0
# 2                                        827945340.0
#
#    Changes in inventories   ...  \
# 0                      NaN  ...
# 1                      NaN  ...
# 2                      NaN  ...
#
#    Household consumption expenditure (including Non-profit institutions serving households)   \
# ...

# %%
df.tail(4)
# Out:
#        CountryID   Country   Year   AMA exchange rate   \
# 10508         894   Zambia    2018           10.458143
# 10509         894   Zambia    2019           12.889418
# 10510         894   Zambia    2020           18.344093
# 10511         894   Zambia    2021           20.018487
#
#        IMF based exchange rate   Population  Currency   Per capita GNI   \
# 10508                 10.458143     17835893   Kwacha              1451
# 10509                 12.889418     18380477   Kwacha              1246
# 10510                 18.344093     18927715   Kwacha               928
# 10511                 20.018487     19473125   Kwacha              1062
#
#        Agriculture, hunting, forestry, fishing (ISIC A-B)   \
# 10508                                        879116033.0
# 10509                                        666838493.0
# 10510                                        539169351.0
# 10511                                        628528683.0
#
# ...

# %%
df.describe()
# Out:
#          CountryID          Year   AMA exchange rate   \
# count  10512.000000  10512.000000        1.051200e+04
# mean     431.116629   1996.262747        3.573959e+02
# std      251.169090     14.900361        2.291128e+03
# min        4.000000   1970.000000        4.300000e-14
# 25%      212.000000   1984.000000        1.000000e+00
# 50%      430.000000   1997.000000        2.812895e+00
# 75%      643.000000   2009.000000        5.134316e+01
# max      894.000000   2021.000000        1.116366e+05
#
#        IMF based exchange rate    Population   Per capita GNI   \
# count              1.051200e+04  1.051200e+04     10512.000000
# mean               3.419846e+02  2.851523e+07      8965.564593
# std                1.941857e+03  1.141296e+08     17070.205895
# min                4.300000e-14  4.359000e+03        34.000000
# 25%                1.000000e+00  6.330615e+05       730.000000
# 50%                2.761315e+00  5.051556e+06      2316.500000
# ...

# %%
df.columns
# Out:
# Index([' CountryID ', ' Country ', ' Year ', ' AMA exchange rate ',
#        ' IMF based exchange rate ', ' Population ', ' Currency ',
#        ' Per capita GNI ',
#        ' Agriculture, hunting, forestry, fishing (ISIC A-B) ',
#        ' Changes in inventories ', ' Construction (ISIC F) ',
#        ' Exports of goods and services ', ' Final consumption expenditure ',
#        ' General government final consumption expenditure ',
#        ' Gross capital formation ',
#        ' Gross fixed capital formation (including Acquisitions less disposals of valuables) ',
#        ' Household consumption expenditure (including Non-profit institutions serving households) ',
#        ' Imports of goods and services ', ' Manufacturing (ISIC D) ',
#        ' Mining, Manufacturing, Utilities (ISIC C-E) ',
#        ' Other Activities (ISIC J-P) ', ' Total Value Added ',
#        ' Transport, storage and communication (ISIC I) ',
# ...

# %%
df.shape
# Out:
# (10512, 26)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10512, step=1)

# %%
df.dtypes
# Out:
# CountryID                                                                                      int64
# Country                                                                                       object
# Year                                                                                           int64
# AMA exchange rate                                                                            float64
# IMF based exchange rate                                                                      float64
# Population                                                                                     int64
# Currency                                                                                      object
# Per capita GNI                                                                                 int64
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           float64
# ...

# %%
df.isnull().count()
# Out:
# CountryID                                                                                    10512
# Country                                                                                      10512
# Year                                                                                         10512
# AMA exchange rate                                                                            10512
# IMF based exchange rate                                                                      10512
# Population                                                                                   10512
# Currency                                                                                     10512
# Per capita GNI                                                                               10512
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           10512
# ...

# %%
df.count()
# Out:
# CountryID                                                                                    10512
# Country                                                                                      10512
# Year                                                                                         10512
# AMA exchange rate                                                                            10512
# IMF based exchange rate                                                                      10512
# Population                                                                                   10512
# Currency                                                                                     10512
# Per capita GNI                                                                               10512
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           10391
# ...

# %%
df.isnull().sum()
# Out:
# CountryID                                                                                       0
# Country                                                                                         0
# Year                                                                                            0
# AMA exchange rate                                                                               0
# IMF based exchange rate                                                                         0
# Population                                                                                      0
# Currency                                                                                        0
# Per capita GNI                                                                                  0
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                            121
# Changes in inventories                                                                       1841
# ...

# %%
df.boxplot()

plt.show()

# %%
df[" Country "].hist()

plt.show()

# %%
df[" Population "].describe()
# Out:
# count    1.051200e+04
# mean     2.851523e+07
# std      1.141296e+08
# min      4.359000e+03
# 25%      6.330615e+05
# 50%      5.051556e+06
# 75%      1.678862e+07
# max      1.425893e+09
# Name:  Population , dtype: float64

# %%
df[" Year "].value_counts()
# Out:
#  Year
# 1990    216
# 2009    214
# 2010    214
# 2008    214
# 2012    213
# 2011    213
# 2014    212
# 2015    212
# 2018    212
# 2007    212
# 2006    212
# 2013    212
# 2005    212
# 2019    212
# 2016    212
# 2017    212
# 2021    212
# 2020    212
# 1992    211
# 1991    211
# 1993    211
# 1996    210
# 1994    210
# 2001    210
# 1995    210
# 2004    210
# 2002    210
# 2003    210
# 1999    210
# 2000    210
# 1998    210
# 1997    210
# 1989    188
# 1988    187
# 1986    187
# 1987    187
# 1971    187
# 1972    187
# 1970    187
# 1985    187
# 1983    187
# 1984    187
# 1982    187
# 1981    187
# 1977    187
# 1980    187
# 1979    187
# 1978    187
# 1975    187
# 1976    187
# 1974    187
# 1973    187
# Name: count, dtype: int64

# %%
df[" Population "].unique()
# Out:
# array([10752971, 11015857, 11286753, ..., 18380477, 18927715, 19473125],
#       shape=(10498,))

# %%
df[[" Currency ", " Year ", " Population "]].describe()
# Out:
#               Year    Population
# count  10512.000000  1.051200e+04
# mean    1996.262747  2.851523e+07
# std       14.900361  1.141296e+08
# min     1970.000000  4.359000e+03
# 25%     1984.000000  6.330615e+05
# 50%     1997.000000  5.051556e+06
# 75%     2009.000000  1.678862e+07
# max     2021.000000  1.425893e+09

# %%
df.groupby(" Country ")[" Population "].max()
# Out:
#  Country
# Afghanistan                   40099462
# Albania                        3303739
# Algeria                       44177969
# Andorra                          80221
# Angola                        34503774
#                                 ...
# Yemen Democratic (Former)      2912315
# Yugoslavia (Former)           23972172
# Zambia                        19473125
# Zanzibar                       1717608
# Zimbabwe                      15993524
# Name:  Population , Length: 220, dtype: int64

# %%
df.groupby(" Country ")[" Population "].mean()
# Out:
#  Country
# Afghanistan                   1.968678e+07
# Albania                       2.987308e+06
# Algeria                       2.815878e+07
# Andorra                       5.646663e+04
# Angola                        1.621307e+07
#                                   ...
# Yemen Democratic (Former)     2.153291e+06
# Yugoslavia (Former)           2.251334e+07
# Zambia                        9.890682e+06
# Zanzibar                      1.121364e+06
# Zimbabwe                      1.055289e+07
# Name:  Population , Length: 220, dtype: float64

# %%
df.groupby(" Country ")[" Population "].sum()
# Out:
#  Country
# Afghanistan                   1023712584
# Albania                        155340035
# Algeria                       1464256518
# Andorra                          2936265
# Angola                         843079816
#                                  ...
# Yemen Democratic (Former)       45219112
# Yugoslavia (Former)            472780099
# Zambia                         514315475
# Zanzibar                        35883657
# Zimbabwe                       548750396
# Name:  Population , Length: 220, dtype: int64

# %%
df.groupby([" Country ", " Year "])[" Population "].max()
# Out:
#  Country       Year
# Afghanistan   1970      10752971
#               1971      11015857
#               1972      11286753
#               1973      11575305
#               1974      11869879
#                           ...
# Zimbabwe      2017      14751101
#               2018      15052184
#               2019      15354608
#               2020      15669666
#               2021      15993524
# Name:  Population , Length: 10512, dtype: int64

# %%
df.groupby([" Country ", " Year "])[" Population "].agg(["sum", "mean", "count", "max", "min", "std"])
# Out:
#                           sum        mean  count       max       min  std
#  Country      Year
# Afghanistan  1970    10752971  10752971.0      1  10752971  10752971  NaN
#              1971    11015857  11015857.0      1  11015857  11015857  NaN
#              1972    11286753  11286753.0      1  11286753  11286753  NaN
#              1973    11575305  11575305.0      1  11575305  11575305  NaN
#              1974    11869879  11869879.0      1  11869879  11869879  NaN
# ...                       ...         ...    ...       ...       ...  ...
# Zimbabwe     2017    14751101  14751101.0      1  14751101  14751101  NaN
#              2018    15052184  15052184.0      1  15052184  15052184  NaN
#              2019    15354608  15354608.0      1  15354608  15354608  NaN
#              2020    15669666  15669666.0      1  15669666  15669666  NaN
#              2021    15993524  15993524.0      1  15993524  15993524  NaN
#
# [10512 rows x 6 columns]

# %%
pd.concat([df, df2], axis = 1)
# Out:
#         CountryID        Country    Year    AMA exchange rate   \
# 0                4   Afghanistan     1970             0.044998
# 1                4   Afghanistan     1971             0.044998
# 2                4   Afghanistan     1972             0.044998
# 3                4   Afghanistan     1973             0.044998
# 4                4   Afghanistan     1974             0.044998
# ...            ...            ...     ...                  ...
# 10507          894        Zambia     2017             9.519501
# 10508          894        Zambia     2018            10.458143
# 10509          894        Zambia     2019            12.889418
# 10510          894        Zambia     2020            18.344093
# 10511          894        Zambia     2021            20.018487
#
#         IMF based exchange rate    Population   Currency    Per capita GNI   \
# 0                       0.044998      10752971   Afghani                164
# ...
