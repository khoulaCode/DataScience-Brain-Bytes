# %%
import pandas as pd
df = pd.read_csv('data/laptopData.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1273 non-null   object
#  3   Inches            1273 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1273 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1273 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

print(df.columns)
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
# 1. drop empty rows (choose how='all' or how='any')
df.dropna(how='all', inplace=True)

# 2. reset the index
df.reset_index(drop=True, inplace=True)

# check
print(df.head())
print(df.columns)
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df.tail()
# Out:
#      Company            TypeName Inches  \
# 1268  Lenovo  2 in 1 Convertible     14
# 1269  Lenovo  2 in 1 Convertible   13.3
# 1270  Lenovo            Notebook     14
# 1271      HP            Notebook   15.6
# 1272    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 1268   IPS Panel Full HD / Touchscreen 1920x1080
# 1269  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1270                                    1366x768
# 1271                                    1366x768
# 1272                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1268            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1269            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1270  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1271            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1272  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
#
# ...

# %%
dup_count = df.duplicated().sum()
print(f"Duplicate rows: {dup_count}")
# Out:
# Duplicate rows: 29

# %%
# 1. Drop duplicates (keeps the first occurrence by default)
df.drop_duplicates(inplace=True)

# 2. Verify: there should be zero duplicate rows now
print(f"Remaining duplicates: {df.duplicated().sum()}")

# 3. (Optional) See how many rows remain
print(f"New row count: {len(df)}")
# Out:
# Remaining duplicates: 0
# New row count: 1244

# %%
# Create a boolean mask: True for rows that contain at least one "?"
mask = df.eq('?').any(axis=1)

# Drop those rows
df = df[~mask].copy()

# (Optional) Check it worked:
print((df == '?').any())   # should all be False
print(df.shape)            # row count should be reduced
# Out:
# Company             False
# TypeName            False
# Inches              False
# ScreenResolution    False
# Cpu                 False
# Ram                 False
# Memory              False
# Gpu                 False
# OpSys               False
# Weight              False
# Price               False
# dtype: bool
# (1241, 11)

# %%
unique_ops = df['OpSys'].unique()
print(unique_ops)
# Out:
# ['macOS' 'No OS' 'Windows 10' 'Mac OS X' 'Linux' 'Windows 10 S'
#  'Chrome OS' 'Windows 7' 'Android']

# %%
import matplotlib.pyplot as plt

os_counts = df['OpSys'].value_counts()

os_counts.plot(kind='bar')

plt.xlabel('Operating System')
plt.ylabel('Number of Laptops')
plt.title('Laptop Counts by OpSys')

plt.tight_layout()
plt.show()

# %%
print(df.isnull().sum())
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
for col in df.select_dtypes('object'):
    df[col] = df[col].str.strip()

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1241 entries, 0 to 1243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1241 non-null   object
#  1   TypeName          1241 non-null   object
#  2   Inches            1241 non-null   object
#  3   ScreenResolution  1241 non-null   object
#  4   Cpu               1241 non-null   object
#  5   Ram               1241 non-null   object
#  6   Memory            1241 non-null   object
#  7   Gpu               1241 non-null   object
#  8   OpSys             1241 non-null   object
#  9   Weight            1241 non-null   object
#  10  Price             1241 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 116.3+ KB
# None

# %%
for col in ['Company','TypeName','OpSys']:
    print(col, df[col].unique())
# Out:
# Company ['Apple' 'HP' 'Acer' 'Asus' 'Dell' 'Lenovo' 'Chuwi' 'MSI' 'Microsoft'
#  'Toshiba' 'Huawei' 'Xiaomi' 'Vero' 'Razer' 'Mediacom' 'Samsung' 'Google'
#  'Fujitsu' 'LG']
# TypeName ['Ultrabook' 'Notebook' 'Gaming' '2 in 1 Convertible' 'Workstation'
#  'Netbook']
# OpSys ['macOS' 'No OS' 'Windows 10' 'Mac OS X' 'Linux' 'Windows 10 S'
#  'Chrome OS' 'Windows 7' 'Android']

# %%
# 6. Quick numeric summary
print(df[['Inches','Price']].describe())
# Out:
#                Price
# count    1241.000000
# mean    60536.425594
# std     37417.445472
# min      9270.720000
# 25%     32639.860800
# 50%     52693.920000
# 75%     79813.440000
# max    324954.720000

# %%
df['Resolution']   = df['ScreenResolution'].str.split().str[-1]
df[['X_res','Y_res']] = df['Resolution'].str.split('x', expand=True).astype(int)
df['Touchscreen']  = df['ScreenResolution'].str.contains('Touch', case=False)

# %%
df['Ram_GB'] = df['Ram'].str.replace('GB','').astype(int)

# %%
df['Weight_kg'] = df['Weight'].str.replace('kg','').astype(float)

# %%
df['Inches'] = df['Inches'].astype(float)

# %%
df['Price']  = df['Price'].astype(float)

# %%
parts = df['Cpu'].str.rsplit(' ', n=1, expand=True)
df['Cpu_Model']    = parts[0]
df['Cpu_Speed_GHz']= parts[1].str.replace('GHz','').astype(float)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1239    Asus            Notebook    15.6
# 1240  Lenovo  2 in 1 Convertible    14.0
# 1241  Lenovo  2 in 1 Convertible    13.3
# 1242  Lenovo            Notebook    14.0
# 1243      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1239                                    1366x768
# 1240   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1241 entries, 0 to 1243
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1241 non-null   object
#  1   TypeName          1241 non-null   object
#  2   Inches            1241 non-null   float64
#  3   ScreenResolution  1241 non-null   object
#  4   Cpu               1241 non-null   object
#  5   Ram               1241 non-null   object
#  6   Memory            1241 non-null   object
#  7   Gpu               1241 non-null   object
#  8   OpSys             1241 non-null   object
#  9   Weight            1241 non-null   object
#  10  Price             1241 non-null   float64
#  11  Resolution        1241 non-null   object
#  12  X_res             1241 non-null   int64
#  13  Y_res             1241 non-null   int64
#  14  Touchscreen       1241 non-null   bool
#  15  Ram_GB            1241 non-null   int64
# ...

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        399
# 1TB HDD                          209
# 500GB HDD                        121
# 512GB SSD                        112
# 128GB SSD +  1TB HDD              92
# 128GB SSD                         72
# 256GB SSD +  1TB HDD              71
# 32GB Flash Storage                35
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           13
# 64GB Flash Storage                12
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 128GB Flash Storage                4
# 180GB SSD                          4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
parts = df['Memory'].str.split(' \+ ', n=1, expand=True)
parts.columns = ['Part1','Part2']

df[['Mem1_Size','Mem1_Type']] = parts['Part1'].str.split(' ', n=1, expand=True)
df[['Mem2_Size','Mem2_Type']] = parts['Part2'].str.split(' ', n=1, expand=True)

df[['Mem2_Size','Mem2_Type']] = df[['Mem2_Size','Mem2_Type']].fillna('Not Available')

print(df[['Memory','Mem1_Size','Mem1_Type','Mem2_Size','Mem2_Type']].head())
# Out:
#                 Memory Mem1_Size      Mem1_Type      Mem2_Size      Mem2_Type
# 0            128GB SSD     128GB            SSD  Not Available  Not Available
# 1  128GB Flash Storage     128GB  Flash Storage  Not Available  Not Available
# 2            256GB SSD     256GB            SSD  Not Available  Not Available
# 3            512GB SSD     512GB            SSD  Not Available  Not Available
# 4            256GB SSD     256GB            SSD  Not Available  Not Available

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1239    Asus            Notebook    15.6
# 1240  Lenovo  2 in 1 Convertible    14.0
# 1241  Lenovo  2 in 1 Convertible    13.3
# 1242  Lenovo            Notebook    14.0
# 1243      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1239                                    1366x768
# 1240   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1241 entries, 0 to 1243
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1241 non-null   object
#  1   TypeName          1241 non-null   object
#  2   Inches            1241 non-null   float64
#  3   ScreenResolution  1241 non-null   object
#  4   Cpu               1241 non-null   object
#  5   Ram               1241 non-null   object
#  6   Memory            1241 non-null   object
#  7   Gpu               1241 non-null   object
#  8   OpSys             1241 non-null   object
#  9   Weight            1241 non-null   object
#  10  Price             1241 non-null   float64
#  11  Resolution        1241 non-null   object
#  12  X_res             1241 non-null   int64
#  13  Y_res             1241 non-null   int64
#  14  Touchscreen       1241 non-null   bool
#  15  Ram_GB            1241 non-null   int64
# ...

# %%
new_cols = [
    'Company', 'TypeName', 'Inches',
    'X_res', 'Y_res', 'Touchscreen',
    'Cpu_Model', 'Cpu_Speed_GHz',
    'Ram_GB',
    'Mem1_Size', 'Mem1_Type',
    'Mem2_Size', 'Mem2_Type',
    'Gpu', 'OpSys', 'Weight_kg'
]

# %%
df_subset = df[new_cols].copy()

# %%
print(df_subset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1241 entries, 0 to 1243
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1241 non-null   object
#  1   TypeName       1241 non-null   object
#  2   Inches         1241 non-null   float64
#  3   X_res          1241 non-null   int64
#  4   Y_res          1241 non-null   int64
#  5   Touchscreen    1241 non-null   bool
#  6   Cpu_Model      1241 non-null   object
#  7   Cpu_Speed_GHz  1241 non-null   float64
#  8   Ram_GB         1241 non-null   int64
#  9   Mem1_Size      1241 non-null   object
#  10  Mem1_Type      1241 non-null   object
#  11  Mem2_Size      1241 non-null   object
#  12  Mem2_Type      1241 non-null   object
#  13  Gpu            1241 non-null   object
#  14  OpSys          1241 non-null   object
#  15  Weight_kg      1241 non-null   float64
# dtypes: bool(1), float64(3), int64(3), object(9)
# memory usage: 156.3+ KB
# None

# %%
df_subset
# Out:
#      Company            TypeName  Inches  X_res  Y_res  Touchscreen  \
# 0      Apple           Ultrabook    13.3   2560   1600        False
# 1      Apple           Ultrabook    13.3   1440    900        False
# 2         HP            Notebook    15.6   1920   1080        False
# 3      Apple           Ultrabook    15.4   2880   1800        False
# 4      Apple           Ultrabook    13.3   2560   1600        False
# ...      ...                 ...     ...    ...    ...          ...
# 1239    Asus            Notebook    15.6   1366    768        False
# 1240  Lenovo  2 in 1 Convertible    14.0   1920   1080         True
# 1241  Lenovo  2 in 1 Convertible    13.3   3200   1800         True
# 1242  Lenovo            Notebook    14.0   1366    768        False
# 1243      HP            Notebook    15.6   1366    768        False
#
#                           Cpu_Model  Cpu_Speed_GHz  Ram_GB Mem1_Size  \
# 0                     Intel Core i5            2.3       8     128GB
# ...
