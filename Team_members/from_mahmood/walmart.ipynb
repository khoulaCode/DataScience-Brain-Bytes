# %%
import pandas as pd
df = pd.read_csv('data/features.csv')

# %%
df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572   10382.90    6115.67
# 1         1  2010-02-12        38.51       2.548   10382.90    6115.67
# 2         1  2010-02-19        39.93       2.514   10382.90    6115.67
# 3         1  2010-02-26        46.63       2.561   10382.90    6115.67
# 4         1  2010-03-05        46.50       2.625   10382.90    6115.67
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
df.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5  Unemployment
# count    3613.000000   3464.000000    4050.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422      7.826821
# std     11276.462208   6792.329861   13086.690278      1.877259
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
df.tail()
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5  CPI  Unemployment  IsHoliday
# 8185       3.00    2449.97    3169.69  NaN           NaN      False
# 8186     582.74    5797.47    1514.93  NaN           NaN      False
# 8187      85.72     744.84    2150.36  NaN           NaN      False
# 8188     204.19     363.00    1059.46  NaN           NaN      False
# 8189       2.06      10.88    1864.57  NaN           NaN      False

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'IsHoliday'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.tail(30)
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8160     45  2013-01-04        32.87       3.592    1341.33   30325.14
# 8161     45  2013-01-11        38.78       3.611    3877.36   15559.85
# 8162     45  2013-01-18        41.45       3.605   14746.10    4071.06
# 8163     45  2013-01-25        26.49       3.583    3130.28    1362.10
# 8164     45  2013-02-01        34.92       3.615   14508.96    1092.53
# 8165     45  2013-02-08        28.99       3.753   53311.88     531.33
# 8166     45  2013-02-15        35.87       3.814    9362.02    2017.68
# 8167     45  2013-02-22        31.48       3.859   10781.51    2735.67
# 8168     45  2013-03-01        39.72       3.890    6614.32     147.82
# 8169     45  2013-03-08        36.13       3.860   16382.54      88.67
# 8170     45  2013-03-15        42.81       3.834    9867.03        NaN
# 8171     45  2013-03-22        36.55       3.800   11923.74        NaN
# ...

# %%
df.ffill(inplace=True)

# %%
df.bfill(inplace=True)

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2011-11-11        59.11       3.297   10382.90    6115.67
# 1         1  2011-11-18        62.25       3.308    6074.12     254.39
# 2         1  2011-11-25        60.14       3.236     410.31      98.00
# 3         1  2011-12-02        48.91       3.172    5629.51      68.00
# 4         1  2011-12-09        43.93       3.158    4640.65      19.00
# ...     ...         ...          ...         ...        ...        ...
# 2064     45  2013-03-01        39.72       3.890    6614.32     147.82
# 2065     45  2013-03-08        36.13       3.860   16382.54      88.67
# 2066     45  2013-04-05        43.94       3.763   16427.83    5341.41
# 2067     45  2013-04-12        57.39       3.724    8760.15    1713.11
# 2068     45  2013-04-19        56.27       3.676    1399.81      39.89
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
df2
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2011-11-11        59.11       3.297   10382.90    6115.67
# 1         1  2011-11-18        62.25       3.308    6074.12     254.39
# 2         1  2011-11-25        60.14       3.236     410.31      98.00
# 3         1  2011-12-02        48.91       3.172    5629.51      68.00
# 4         1  2011-12-09        43.93       3.158    4640.65      19.00
# ...     ...         ...          ...         ...        ...        ...
# 2064     45  2013-03-01        39.72       3.890    6614.32     147.82
# 2065     45  2013-03-08        36.13       3.860   16382.54      88.67
# 2066     45  2013-04-05        43.94       3.763   16427.83    5341.41
# 2067     45  2013-04-12        57.39       3.724    8760.15    1713.11
# 2068     45  2013-04-19        56.27       3.676    1399.81      39.89
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
df2.to_csv("cleaned_walmart.csv", index=False)

# %%
# !pip install openpyxl

# %%
df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572   10382.90    6115.67
# 1         1  2010-02-12        38.51       2.548   10382.90    6115.67
# 2         1  2010-02-19        39.93       2.514   10382.90    6115.67
# 3         1  2010-02-26        46.63       2.561   10382.90    6115.67
# 4         1  2010-03-05        46.50       2.625   10382.90    6115.67
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd
df2 = pd.read_csv('data/train.csv')
df2
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
df2.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday'], dtype='object')

# %%
df2['Weekly_Sales'].unique()
# Out:
# array([24924.5 , 46039.49, 41595.55, ...,  1061.02,   760.01,  1076.8 ])

# %%
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd
df3 = pd.read_csv('data/stores.csv')
df3
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
df3.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
df3.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'IsHoliday'],
#       dtype='object')

# %%
print(df['Unemployment'].sum())
# Out:
# 63453.731999999996

# %%
df.groupby('MarkDown3')['MarkDown5'].sum()
# Out:
# MarkDown3
# -179.26        6333.87
# -89.10         1549.09
# -44.54         1098.99
# -29.10        11752.37
# -23.97         2662.80
#                 ...
#  130129.11     2481.14
#  139621.51     1415.02
#  141630.61     1009.98
#  146394.44     1005.18
#  149483.31     1176.10
# Name: MarkDown5, Length: 2885, dtype: float64

# %%
df.groupby('Unemployment')['MarkDown5'].count()
# Out:
# Unemployment
# 3.684     34
# 3.879     13
# 3.896     17
# 3.921     13
# 3.932     26
#           ..
# 13.975    24
# 14.021    36
# 14.099    39
# 14.180    39
# 14.313    42
# Name: MarkDown5, Length: 404, dtype: int64

# %%
df2
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
df3
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...
