# %%
import pandas as pd
df = pd.read_csv('household_power_consumption.txt', delimiter=';', low_memory=False)
df
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                 0.000
# 2075255  26/11/2010  20:59:00               0.944                 0.000
# 2075256  26/11/2010  21:00:00               0.938                 0.000
# 2075257  26/11/2010  21:01:00               0.934                 0.000
# 2075258  26/11/2010  21:02:00               0.932                 0.000
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                     0
# Time                     0
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %%
df_float = ['Global_active_power', 'Global_reactive_power',
       'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
       'Sub_metering_3']
df.loc[:, df_float]= df[df_float].astype(float)
df.dtypes
# Out:
# Date                     datetime64[ns]
# Time                             object
# Global_active_power             float64
# Global_reactive_power           float64
# Voltage                         float64
# Global_intensity                float64
# Sub_metering_1                  float64
# Sub_metering_2                  float64
# Sub_metering_3                  float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.loc[:, 'Date'] = pd.to_datetime(df['Date'], dayfirst=True)
df.Date
# Out:
# 0         2006-12-16
# 1         2006-12-16
# 2         2006-12-16
# 3         2006-12-16
# 4         2006-12-16
#              ...
# 2075254   2010-11-26
# 2075255   2010-11-26
# 2075256   2010-11-26
# 2075257   2010-11-26
# 2075258   2010-11-26
# Name: Date, Length: 2049280, dtype: datetime64[ns]

# %%
df.describe()
# Out:
#                                 Date  Global_active_power  \
# count                        2049280         2.049280e+06
# mean   2008-12-01 13:00:00.309181952         1.091615e+00
# min              2006-12-16 00:00:00         7.600000e-02
# 25%              2007-12-10 00:00:00         3.080000e-01
# 50%              2008-11-30 00:00:00         6.020000e-01
# 75%              2009-11-23 00:00:00         1.528000e+00
# max              2010-11-26 00:00:00         1.112200e+01
# std                              NaN         1.057294e+00
#
#        Global_reactive_power       Voltage  Global_intensity  Sub_metering_1  \
# count           2.049280e+06  2.049280e+06      2.049280e+06    2.049280e+06
# mean            1.237145e-01  2.408399e+02      4.627759e+00    1.121923e+00
# min             0.000000e+00  2.232000e+02      2.000000e-01    0.000000e+00
# 25%             4.800000e-02  2.389900e+02      1.400000e+00    0.000000e+00
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(df['Global_reactive_power'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Global_reactive_power')
plt.ylabel('Frequency')
plt.title("Global reactive power")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Time'], df['Global_active_power'], color='red', linewidth=0.5)
plt.xlabel('Time')
plt.ylabel('Global Active Power (kilowatts)')
plt.title('Global Active Power Over Time')
plt.grid(True)
plt.show()

# %%
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str))
# Out:
# C:\Users\bbuser\AppData\Local\Temp\ipykernel_23728\3467620425.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str))
